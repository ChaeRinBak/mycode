# %%
inputt='...'
a=0
c=0
g=0
t=0
for char in inputt :
    if char=='A' :
        a+=1
    elif char=='C' :
        c+=1
    elif char=='G' :
        g+=1
    else :
        t+=1
print(a,c,g,t)
# Out:
# 198 206 235 215

# %%
s='...'
s=s.replace('T','U')
        
print(s)
# Out:
# ...

# %%
f=open("C:\\Users\\cofls\\Downloads\\rosalind_revc.txt", 'r')
inp= f.readlines()
for line in inp:
    line = line.strip()
    print(line)
f.close()

inp=line
# Out:
# ...

# %%
res=''
nts={'A':'T','T':'A','G':'C','C':'G'}

for c in inp :
    res=nts[c]+res
    
print(res)
# Out:
# ...
