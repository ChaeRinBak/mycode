# %%
s='''GAGCCTACTAACGGGAT'''
t='''CATCGTAATGACGGCCT'''

s='''...'''
t='''...'''

# %%
res=0

for i in range(len(s)) :
    if s[i]==t[i] :
        continue
    else :
        res+=1
print(res)
# Out:
# 473
